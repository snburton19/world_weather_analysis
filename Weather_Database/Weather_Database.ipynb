# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind_speed,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | kerrobert
# Processing Record 3 of Set 1 | buala
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | sept-iles
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | naraina
# Processing Record 12 of Set 1 | bogotol
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | tabou
# Processing Record 15 of Set 1 | deputatskiy
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 1 | ingleside
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | pithoragarh
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 28 of Set 1 | ketchikan
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | waiouru
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | clarksburg
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | mnogovershinnyy
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | alta floresta
# Processing Record 44 of Set 1 | westport
# Processing Record 45 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | winnemucca
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 2 | victor harbor
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | coahuayana
# Processing Record 10 of Set 2 | xuchang
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | homer
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | berlevag
# Processing Record 15 of Set 2 | sidi ali
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | casper
# Processing Record 19 of Set 2 | itarema
# Processing Record 20 of Set 2 | upata
# Processing Record 21 of Set 2 | vallenar
# Processing Record 22 of Set 2 | bawisan
# City not found. Skipping...
# Processing Record 23 of Set 2 | sudbury
# Processing Record 24 of Set 2 | kapoeta
# Processing Record 25 of Set 2 | vilhena
# Processing Record 26 of Set 2 | belyy yar
# Processing Record 27 of Set 2 | seoul
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | leer
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | tyup
# Processing Record 35 of Set 2 | half moon bay
# Processing Record 36 of Set 2 | muisne
# Processing Record 37 of Set 2 | mehamn
# Processing Record 38 of Set 2 | arlit
# Processing Record 39 of Set 2 | guerrero negro
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | ko samui
# Processing Record 42 of Set 2 | darhan
# Processing Record 43 of Set 2 | nhulunbuy
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | tecate
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | lata
# Processing Record 50 of Set 2 | bjornevatn
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | ardesen
# Processing Record 4 of Set 3 | vuktyl
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | quatre cocos
# Processing Record 8 of Set 3 | port lincoln
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | edson
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | los llanos de aridane
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | lodeynoye pole
# Processing Record 15 of Set 3 | shenzhen
# Processing Record 16 of Set 3 | manokwari
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | la mira
# Processing Record 19 of Set 3 | busselton
# Processing Record 20 of Set 3 | shahr-e kord
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | marystown
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | minas
# Processing Record 25 of Set 3 | kanashevo
# Processing Record 26 of Set 3 | manthani
# Processing Record 27 of Set 3 | healdsburg
# Processing Record 28 of Set 3 | nenjiang
# Processing Record 29 of Set 3 | lixourion
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | berezovyy
# Processing Record 33 of Set 3 | san jeronimo
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | klaksvik
# Processing Record 38 of Set 3 | coxim
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | kinango
# Processing Record 41 of Set 3 | toguchin
# Processing Record 42 of Set 3 | nelson bay
# Processing Record 43 of Set 3 | la libertad
# Processing Record 44 of Set 3 | mestia
# Processing Record 45 of Set 3 | slave lake
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | shirokiy
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | marshall
# Processing Record 50 of Set 3 | andrelandia
# Processing Record 1 of Set 4 | panguipulli
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | chany
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | zyryanka
# Processing Record 8 of Set 4 | itacare
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | vostok
# Processing Record 13 of Set 4 | san policarpo
# Processing Record 14 of Set 4 | mecca
# Processing Record 15 of Set 4 | rumphi
# Processing Record 16 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 4 | korla
# Processing Record 18 of Set 4 | linhares
# Processing Record 19 of Set 4 | muros
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | jacareacanga
# Processing Record 23 of Set 4 | egvekinot
# Processing Record 24 of Set 4 | lamar
# Processing Record 25 of Set 4 | pevek
# Processing Record 26 of Set 4 | lorengau
# Processing Record 27 of Set 4 | ahipara
# Processing Record 28 of Set 4 | turbo
# Processing Record 29 of Set 4 | kaniama
# Processing Record 30 of Set 4 | vestmannaeyjar
# Processing Record 31 of Set 4 | cankuzo
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | srednekolymsk
# Processing Record 35 of Set 4 | tsiroanomandidy
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | marsh harbour
# Processing Record 38 of Set 4 | tambopata
# Processing Record 39 of Set 4 | mogadishu
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | calabar
# Processing Record 42 of Set 4 | pacific grove
# Processing Record 43 of Set 4 | spirit river
# Processing Record 44 of Set 4 | kalmanka
# Processing Record 45 of Set 4 | olafsvik
# Processing Record 46 of Set 4 | acarau
# Processing Record 47 of Set 4 | tulum
# Processing Record 48 of Set 4 | yangjiang
# Processing Record 49 of Set 4 | maan
# Processing Record 50 of Set 4 | talara
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 3 of Set 5 | tromso
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | cooma
# Processing Record 6 of Set 5 | ulaangom
# Processing Record 7 of Set 5 | liverpool
# Processing Record 8 of Set 5 | mareeba
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | carutapera
# Processing Record 12 of Set 5 | fukue
# Processing Record 13 of Set 5 | osoyoos
# Processing Record 14 of Set 5 | walvis bay
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | camacha
# Processing Record 17 of Set 5 | taksimo
# Processing Record 18 of Set 5 | bonavista
# Processing Record 19 of Set 5 | tinde
# Processing Record 20 of Set 5 | ishigaki
# Processing Record 21 of Set 5 | lashio
# Processing Record 22 of Set 5 | hovd
# Processing Record 23 of Set 5 | parkes
# Processing Record 24 of Set 5 | axim
# Processing Record 25 of Set 5 | yar-sale
# Processing Record 26 of Set 5 | tacuati
# Processing Record 27 of Set 5 | lumeje
# Processing Record 28 of Set 5 | nohar
# Processing Record 29 of Set 5 | fairbanks
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | alyangula
# Processing Record 33 of Set 5 | kozan
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | saint-pierre
# Processing Record 36 of Set 5 | colares
# Processing Record 37 of Set 5 | port keats
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | bushehr
# Processing Record 40 of Set 5 | gashua
# Processing Record 41 of Set 5 | newport
# Processing Record 42 of Set 5 | ayr
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | aksarka
# Processing Record 45 of Set 5 | sobolevo
# Processing Record 46 of Set 5 | dongen
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | middlebury
# Processing Record 49 of Set 5 | riyadh
# Processing Record 50 of Set 5 | devonport
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | nyrob
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | tual
# Processing Record 6 of Set 6 | asasa
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | aquiraz
# Processing Record 9 of Set 6 | great bend
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | saint-augustin
# Processing Record 12 of Set 6 | sagaing
# Processing Record 13 of Set 6 | saint-ambroise
# Processing Record 14 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 6 | vao
# Processing Record 18 of Set 6 | madang
# Processing Record 19 of Set 6 | kampong cham
# Processing Record 20 of Set 6 | guane
# Processing Record 21 of Set 6 | bojnurd
# Processing Record 22 of Set 6 | cochrane
# Processing Record 23 of Set 6 | karla
# Processing Record 24 of Set 6 | bathsheba
# Processing Record 25 of Set 6 | pareora
# Processing Record 26 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 6 | yining
# Processing Record 28 of Set 6 | pangnirtung
# Processing Record 29 of Set 6 | kommunisticheskiy
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | claveria
# Processing Record 32 of Set 6 | port-cartier
# Processing Record 33 of Set 6 | nantucket
# Processing Record 34 of Set 6 | santa isabel
# Processing Record 35 of Set 6 | liwale
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | matara
# Processing Record 38 of Set 6 | cherskiy
# Processing Record 39 of Set 6 | shimoda
# Processing Record 40 of Set 6 | faxinal
# Processing Record 41 of Set 6 | wenling
# Processing Record 42 of Set 6 | mana
# Processing Record 43 of Set 6 | bose
# Processing Record 44 of Set 6 | mahon
# Processing Record 45 of Set 6 | kavaratti
# Processing Record 46 of Set 6 | biloela
# Processing Record 47 of Set 6 | bengkulu
# Processing Record 48 of Set 6 | zhizdra
# Processing Record 49 of Set 6 | dali
# Processing Record 50 of Set 6 | hernani
# Processing Record 1 of Set 7 | porto novo
# Processing Record 2 of Set 7 | tottori
# Processing Record 3 of Set 7 | mongu
# Processing Record 4 of Set 7 | kropotkin
# Processing Record 5 of Set 7 | marienburg
# Processing Record 6 of Set 7 | rocha
# Processing Record 7 of Set 7 | ofaqim
# Processing Record 8 of Set 7 | mangaratiba
# Processing Record 9 of Set 7 | strathpeffer
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | omboue
# Processing Record 12 of Set 7 | bria
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | luau
# Processing Record 15 of Set 7 | key largo
# Processing Record 16 of Set 7 | karachi
# Processing Record 17 of Set 7 | ust-maya
# Processing Record 18 of Set 7 | rio gallegos
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | kaitangata
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | moroni
# Processing Record 23 of Set 7 | tres arroyos
# Processing Record 24 of Set 7 | dabakala
# Processing Record 25 of Set 7 | klyuchi
# Processing Record 26 of Set 7 | tokur
# Processing Record 27 of Set 7 | talcahuano
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | roald
# Processing Record 31 of Set 7 | svetlogorsk
# Processing Record 32 of Set 7 | skovorodino
# Processing Record 33 of Set 7 | naze
# Processing Record 34 of Set 7 | kahului
# Processing Record 35 of Set 7 | tura
# Processing Record 36 of Set 7 | prince rupert
# Processing Record 37 of Set 7 | kosh-agach
# Processing Record 38 of Set 7 | domoni
# Processing Record 39 of Set 7 | saint george
# Processing Record 40 of Set 7 | helong
# Processing Record 41 of Set 7 | gazanjyk
# Processing Record 42 of Set 7 | arkhangelskoye
# Processing Record 43 of Set 7 | tazovskiy
# Processing Record 44 of Set 7 | boende
# Processing Record 45 of Set 7 | caconda
# Processing Record 46 of Set 7 | hamilton
# Processing Record 47 of Set 7 | salta
# Processing Record 48 of Set 7 | sitka
# Processing Record 49 of Set 7 | geraldton
# Processing Record 50 of Set 7 | poplar bluff
# Processing Record 1 of Set 8 | otane
# Processing Record 2 of Set 8 | melnikovo
# Processing Record 3 of Set 8 | qasigiannguit
# Processing Record 4 of Set 8 | safford
# Processing Record 5 of Set 8 | mahibadhoo
# Processing Record 6 of Set 8 | guajara
# Processing Record 7 of Set 8 | flin flon
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | labuhan
# Processing Record 10 of Set 8 | arman
# Processing Record 11 of Set 8 | alofi
# Processing Record 12 of Set 8 | pudozh
# Processing Record 13 of Set 8 | esmeraldas
# Processing Record 14 of Set 8 | yaan
# Processing Record 15 of Set 8 | tessalit
# Processing Record 16 of Set 8 | carnarvon
# Processing Record 17 of Set 8 | semnan
# Processing Record 18 of Set 8 | la asuncion
# Processing Record 19 of Set 8 | tuatapere
# Processing Record 20 of Set 8 | salalah
# Processing Record 21 of Set 8 | baracoa
# Processing Record 22 of Set 8 | jiazi
# Processing Record 23 of Set 8 | filadelfia
# Processing Record 24 of Set 8 | dicabisagan
# Processing Record 25 of Set 8 | litovko
# Processing Record 26 of Set 8 | ancud
# Processing Record 27 of Set 8 | nador
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | dasoguz
# Processing Record 30 of Set 8 | husavik
# Processing Record 31 of Set 8 | seaham
# Processing Record 32 of Set 8 | vytegra
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | flinders
# Processing Record 35 of Set 8 | kautokeino
# Processing Record 36 of Set 8 | bang len
# Processing Record 37 of Set 8 | calama
# Processing Record 38 of Set 8 | thunder bay
# Processing Record 39 of Set 8 | havre-saint-pierre
# Processing Record 40 of Set 8 | lumphat
# Processing Record 41 of Set 8 | kaz
# Processing Record 42 of Set 8 | hokitika
# Processing Record 43 of Set 8 | antalaha
# Processing Record 44 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 8 | barrie
# Processing Record 46 of Set 8 | padang
# Processing Record 47 of Set 8 | antequera
# Processing Record 48 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 50 of Set 8 | ye
# City not found. Skipping...
# Processing Record 1 of Set 9 | mananara
# Processing Record 2 of Set 9 | cockburn town
# Processing Record 3 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 9 | do gonbadan
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | college
# Processing Record 7 of Set 9 | eureka
# Processing Record 8 of Set 9 | sabzevar
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | lazaro cardenas
# Processing Record 11 of Set 9 | tiksi
# Processing Record 12 of Set 9 | batemans bay
# Processing Record 13 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 9 | nangomba
# Processing Record 15 of Set 9 | rozkishne
# Processing Record 16 of Set 9 | portland
# Processing Record 17 of Set 9 | plettenberg bay
# Processing Record 18 of Set 9 | fort-shevchenko
# Processing Record 19 of Set 9 | lakatoro
# Processing Record 20 of Set 9 | labuan
# Processing Record 21 of Set 9 | agsu
# City not found. Skipping...
# Processing Record 22 of Set 9 | weyburn
# Processing Record 23 of Set 9 | vila
# Processing Record 24 of Set 9 | kruisfontein
# Processing Record 25 of Set 9 | coihaique
# Processing Record 26 of Set 9 | molepolole
# Processing Record 27 of Set 9 | oromocto
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | gupitan
# Processing Record 30 of Set 9 | hay river
# Processing Record 31 of Set 9 | ballina
# Processing Record 32 of Set 9 | kafue
# Processing Record 33 of Set 9 | elizabethtown
# Processing Record 34 of Set 9 | irondale
# Processing Record 35 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 9 | chepo
# Processing Record 37 of Set 9 | shelburne
# Processing Record 38 of Set 9 | eyl
# Processing Record 39 of Set 9 | cincinnati
# Processing Record 40 of Set 9 | okha
# Processing Record 41 of Set 9 | kabanjahe
# Processing Record 42 of Set 9 | puerto madryn
# Processing Record 43 of Set 9 | kalengwa
# Processing Record 44 of Set 9 | scarborough
# Processing Record 45 of Set 9 | guantanamo
# Processing Record 46 of Set 9 | kihei
# Processing Record 47 of Set 9 | whitehorse
# Processing Record 48 of Set 9 | teya
# Processing Record 49 of Set 9 | la ronge
# Processing Record 50 of Set 9 | sisimiut
# Processing Record 1 of Set 10 | oksfjord
# Processing Record 2 of Set 10 | yeppoon
# Processing Record 3 of Set 10 | kodinsk
# Processing Record 4 of Set 10 | oussouye
# Processing Record 5 of Set 10 | sarkand
# Processing Record 6 of Set 10 | takob
# City not found. Skipping...
# Processing Record 7 of Set 10 | broome
# Processing Record 8 of Set 10 | kendari
# Processing Record 9 of Set 10 | abnub
# Processing Record 10 of Set 10 | kuminskiy
# Processing Record 11 of Set 10 | jega
# Processing Record 12 of Set 10 | conceicao do araguaia
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | bilibino
# Processing Record 15 of Set 10 | suwannaphum
# Processing Record 16 of Set 10 | santa
# Processing Record 17 of Set 10 | lethem
# Processing Record 18 of Set 10 | lebu
# Processing Record 19 of Set 10 | derzhavinsk
# Processing Record 20 of Set 10 | jizan
# Processing Record 21 of Set 10 | tawang
# Processing Record 22 of Set 10 | berbera
# Processing Record 23 of Set 10 | siniscola
# Processing Record 24 of Set 10 | painesville
# Processing Record 25 of Set 10 | petrozavodsk
# Processing Record 26 of Set 10 | manoleasa
# Processing Record 27 of Set 10 | las palmas
# Processing Record 28 of Set 10 | emba
# Processing Record 29 of Set 10 | kamaishi
# Processing Record 30 of Set 10 | qazvin
# Processing Record 31 of Set 10 | kabwe
# Processing Record 32 of Set 10 | severo-kurilsk
# Processing Record 33 of Set 10 | ban nahin
# Processing Record 34 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 10 | ben tre
# Processing Record 36 of Set 10 | adrar
# Processing Record 37 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 38 of Set 10 | havelock
# Processing Record 39 of Set 10 | sestri levante
# Processing Record 40 of Set 10 | kenai
# Processing Record 41 of Set 10 | peterhead
# Processing Record 42 of Set 10 | aksay
# Processing Record 43 of Set 10 | guanica
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | sao filipe
# Processing Record 46 of Set 10 | chipinge
# Processing Record 47 of Set 10 | celestun
# Processing Record 48 of Set 10 | yondo
# Processing Record 49 of Set 10 | laiwu
# Processing Record 50 of Set 10 | kedougou

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     60.91        48          40
# 1     Egvekinot      RU  66.3167 -179.1667     12.34        97         100
# 2      Saldanha      ZA -33.0117   17.9442     71.65        71          50
# 3     Upernavik      GL  72.7868  -56.1549     -1.59        92         100
# 4      Cherskiy      RU  68.7500  161.3000    -19.68        95         100
# 5     Bonavista      CA  48.6499  -53.1147     25.97        60          40
# 6       Ushuaia      AR -54.8000  -68.3000     58.66        47          20
# 7         Moree      AU -29.4667  149.8500     78.57        52           4
# 8        Atuona      PF  -9.8000 -139.0333     78.71        79          97
# 9   Port Alfred      ZA -33.5906   26.8910     68.18        90          39
#
#    Wind Speed Current Description
# 0       36.82    scattered clouds
# 1        2.17          light snow
# 2       33.80    scattered clouds
# 3        2.84     overcast clouds
# 4        1.23     overcast clouds
# 5        3.38    scattered clouds
# 6       26.46          few clouds
# 7       13.56           clear sky
# 8       20.42     overcast clouds
# 9        5.01          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"
column_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_reordered_df = city_data_df[column_list]

# Display sample data
city_data_reordered_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     60.91        48          40
# 1     Egvekinot      RU  66.3167 -179.1667     12.34        97         100
# 2      Saldanha      ZA -33.0117   17.9442     71.65        71          50
# 3     Upernavik      GL  72.7868  -56.1549     -1.59        92         100
# 4      Cherskiy      RU  68.7500  161.3000    -19.68        95         100
#
#    Wind Speed Current Description
# 0       36.82    scattered clouds
# 1        2.17          light snow
# 2       33.80    scattered clouds
# 3        2.84     overcast clouds
# 4        1.23     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_reordered_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_reordered_df.to_csv(output_file, index_label="City_ID")
